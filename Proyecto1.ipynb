# %% [markdown]
# <a href="https://colab.research.google.com/github/constanzego/proyecciones_ventas/blob/main/Proyecto1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# importar modelo de regresión lineal
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve, roc_auc_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

from pandas.plotting import scatter_matrix
from sklearn.metrics import confusion_matrix,accuracy_score,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/Proyecto1/sales_predictions.csv'
df = pd.read_csv(filename)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.loc[:, df.isna().any()]
# Out:
#       Item_Weight Outlet_Size
# 0           9.300      Medium
# 1           5.920      Medium
# 2          17.500      Medium
# 3          19.200         NaN
# 4           8.930        High
# ...           ...         ...
# 8518        6.865        High
# 8519        8.380         NaN
# 8520       10.600       Small
# 8521        7.210      Medium
# 8522       14.800       Small
#
# [8523 rows x 2 columns]

# %% [markdown]
# **Item_Weight**

# %%
df['Item_Weight'].isna().value_counts()
# Out:
# False    7060
# True     1463
# Name: Item_Weight, dtype: int64

# %%
missing1=df['Item_Weight'].isna()

# %%
avg_w= df['Item_Weight'].sum()/len(missing1)

# %%
df.loc[:,'Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# **Oulet_Size**

# %%
df['Outlet_Size'].isna().value_counts()
# Out:
# False    6113
# True     2410
# Name: Outlet_Size, dtype: int64

# %%
missing2=df['Outlet_Size'].isna()

# %%
df.loc[missing2,:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
filter_outlet_small= df['Outlet_Size'] == 'Small' 
filter_outlet_medium= df['Outlet_Size'] == 'Medium'
filter_outlet_high= df['Outlet_Size'] == 'High'

# %%
df.loc[filter_outlet_small,:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11             FDA03        18.50          Regular         0.045464
# 13             FDS46        17.60          Regular         0.047257
# 15             FDP49         9.00          Regular         0.069089
# 19             FDU02        13.35          Low Fat         0.102492
# 22             NCB30        14.60          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 8510           FDN58        13.80          Regular         0.056862
# 8513           FDH31        12.00          Regular         0.020407
# 8517           FDF53        20.75              reg         0.083607
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 11                 Dairy  144.1102            OUT046
# ...

# %%
df.loc[filter_outlet_medium,:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 1              DRC01     5.920000          Regular         0.019278
# 2              FDN15    17.500000          Low Fat         0.016760
# 5              FDP36    10.395000          Regular         0.000000
# 7              FDP10    12.857645          Low Fat         0.127470
# ...              ...          ...              ...              ...
# 8506           DRF37    17.250000          Low Fat         0.084676
# 8511           FDF05    17.500000          Low Fat         0.026980
# 8515           FDH24    20.700000          Low Fat         0.021518
# 8516           NCJ19    18.600000          Low Fat         0.118661
# 8521           FDN46     7.210000          Regular         0.145221
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0            Dairy  249.8092            OUT049                       1999
# ...

# %%
df.loc[filter_outlet_high,:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# ...

# %%
df[['Outlet_Size','Outlet_Type']].value_counts()
# Out:
# Outlet_Size  Outlet_Type
# Small        Supermarket Type1    1860
# Medium       Supermarket Type3     935
# High         Supermarket Type1     932
# Medium       Supermarket Type1     930
#              Supermarket Type2     928
# Small        Grocery Store         528
# dtype: int64

# %%
df.groupby(['Outlet_Type']).mean()
# Out:
#                    Item_Weight  Item_Visibility    Item_MRP  \
# Outlet_Type
# Grocery Store        12.886091         0.104862  140.294688
# Supermarket Type1    12.849509         0.060723  141.213894
# Supermarket Type2    12.873346         0.061014  141.678634
# Supermarket Type3    12.857645         0.058615  139.801791
#
#                    Outlet_Establishment_Year  Item_Outlet_Sales
# Outlet_Type
# Grocery Store                    1991.662050         339.828500
# Supermarket Type1                1999.322933        2316.181148
# Supermarket Type2                2009.000000        1995.498739
# Supermarket Type3                1985.000000        3694.038558

# %%
filter_outlet_small= df['Outlet_Type'] == 'Grocery Store'

# %%
grocery= df.loc[filter_outlet_small, 'Outlet_Size':]

# %%
df.loc[filter_outlet_small, 'Item_Weight'].min()
# Out:
# 4.61

# %%
df.loc[filter_outlet_medium, 'Item_Weight'].max()
# Out:
# 21.35

# %%
df.loc[filter_outlet_medium, 'Item_Weight'].min()
# Out:
# 4.555

# %%
df.loc[missing2,:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
df['Outlet_Size'].replace(to_replace = np.nan, value ="Medium", inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# **Visualizaciones**

# %%
plt.figure(figsize=(12,12))
plt.bar( df['Outlet_Type'], df['Item_Outlet_Sales'], label= "3% Interest")
plt.title("Item Outlet Sales per Outlet Type", fontsize=20)
plt.ylabel("Item_Outlet_Sales", fontsize=20)
plt.xlabel("Outlet Type", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.bar(df['Item_Type'], df['Item_Weight'],  label= "3% Interest")
plt.title("Item Weight per Item Type", fontsize=20)
plt.ylabel("Item_Weight", fontsize=20)
plt.xlabel("Item_Type", fontsize=20)
plt.show()

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
df.corr().sort_values(by = ['Item_Outlet_Sales'])
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Visibility              -0.012049         1.000000 -0.001315
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_MRP                      0.024756        -0.001315  1.000000
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Visibility                            -0.074834          -0.128625
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Weight                                -0.008301           0.011550
# Item_MRP                                    0.005020           0.567574
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(df.corr().sort_values(by = ['Item_Outlet_Sales']), cmap = sns.diverging_palette(240, 10, n=9))

# %%
df.loc[:,:].hist(bins=25,
                 figsize=(16,16),
                 xlabelsize='10',
                 ylabelsize='10',xrot=-15);

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 3,figsize = (10,2), dpi=1000)
sns.regplot(x='Item_Weight', y='Item_Outlet_Sales', data=df, ci=None, ax = axes[0], scatter_kws={'alpha':0.3});
sns.regplot(x='Item_Visibility', y='Item_Outlet_Sales', data=df, ci=None, ax = axes[1], scatter_kws={'alpha':0.3});
sns.regplot(x='Item_MRP', y='Item_Outlet_Sales', data=df, ci=None, ax = axes[2], scatter_kws={'alpha':0.3});
sns.regplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, ci=None, ax = axes[2], scatter_kws={'alpha':0.3});
fig.tight_layout()

# %%
X = df.loc[:, ['Item_Weight', 'Item_Visibility']].values

# %%
X.shape
# Out:
# (8523, 2)

# %%
y = df.loc[:, 'Item_Outlet_Sales'].values

# %%
y.shape
# Out:
# (8523,)

# %%
reg = LinearRegression(fit_intercept=True)

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.predict(X[0].reshape(-1,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-2be94475f61e> in <module>()
# ----> 1 reg.predict(X[0].reshape(-1,3))
#
# ValueError: cannot reshape array of size 2 into shape (3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Se instancia el método de regresión lineal
reg_sales = LinearRegression()

# Se entrena el modelo, y 
reg_sales.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predict_LR = reg_sales.predict(X_test)
predict_LR
# Out:
# array([2491.05588231, 2199.65584675, 2029.50687857, ..., 2009.45053661,
#        2409.35811205, 2249.36404337])

# %%
print("Valores del dataset: \n",y_test[:30])
print("Valores predichos: \n",predict_LR[:30])
# Out:
# Valores del dataset:
#  [ 191.7504  517.3266 1887.543   965.41    635.1732 1617.894   183.095
#  3705.177   897.4984 1018.674  5382.993  5105.3544 2141.2128 3547.3824
#  3095.97   2807.0128  751.0224  830.9184 3844.995  1443.4544 3645.255
#  2390.222  2250.404  4291.7468 1384.1982 2386.2272 1581.9408 2709.806
#   517.3266 1230.3984]
# Valores predichos:
#  [2491.05588231 2199.65584675 2029.50687857 2318.07989437 2302.67166793
#  2046.15416772 1890.22513787 2120.59940172 2084.71356442 2315.72882412
#  2308.71982417 1942.05963236 2405.55513136 2236.61801758 2287.766066
#  2225.25941119 2400.73022975 1968.8017657  2490.42785161 2341.70184945
#  2295.02739329 1849.97540237 1826.247497   2494.82406653 2171.16289446
#  2301.00348417 2255.01198554 1952.24694238 2446.75878334 1971.61467583]

# %%
print("R cuadrado",np.round(r2_score(y_test, predict_LR),3))
print("Raíz del error medio cuadrado",np.round(np.sqrt(mean_squared_error(y_test, predict_LR)),3))
# Out:
# R cuadrado 0.017
# Raíz del error medio cuadrado 1661.004

# %%
knn_sales = KNeighborsRegressor()

knn_sales.fit(X_train, y_train)

predict_knn = knn_sales.predict(X_test)

# %%
print("Valores del dataset: \n",y_test[:30])
print("Valores predichos: \n",predict_knn[:30])
# Out:
# Valores del dataset:
#  [ 191.7504  517.3266 1887.543   965.41    635.1732 1617.894   183.095
#  3705.177   897.4984 1018.674  5382.993  5105.3544 2141.2128 3547.3824
#  3095.97   2807.0128  751.0224  830.9184 3844.995  1443.4544 3645.255
#  2390.222  2250.404  4291.7468 1384.1982 2386.2272 1581.9408 2709.806
#   517.3266 1230.3984]
# Valores predichos:
#  [2238.4196  1486.33192 3298.50636 1448.115   1093.9094  1306.2996
#  1087.65088 1519.3556  2483.83348 1455.17248 4099.73008 1755.98092
#  1790.73568 1820.82984 2507.00332 1843.73336 2569.72168 2477.97444
#  1886.2114  2510.066   2585.16824 4193.07524 3636.46644 2104.06116
#   765.80316 3296.10948 1613.63288 1291.11936 1178.19968 2166.64636]

# %%
print("R cuadrado",np.round(r2_score(y_test, predict_knn),3))
print("Raíz del error medio cuadrado",np.round(np.sqrt(mean_squared_error(y_test, predict_knn)),3))
# Out:
# R cuadrado -0.03
# Raíz del error medio cuadrado 1700.627

# %% [markdown]
# Para la Regresión lineal el R cuadrado es de 0.017 y la raíz del error medio cuadrado es 1661.
# Para el KNN, R cuadrado es de 0 y la raíz del error medio cuadrado es 1700.6 .
# Es una pequeña diferencia pero la regresión lineal es un mejor modelo por tener un menor r cuadrado y raiz del error medio cuadrado.
